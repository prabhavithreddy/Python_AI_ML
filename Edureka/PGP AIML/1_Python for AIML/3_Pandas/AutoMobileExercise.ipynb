# %%
import pandas as pd

# %%
df = pd.read_csv("Automobile_data.csv", index_col='index')

# %% [markdown]
# Exercise 1: From the given dataset print the first and last five rows

# %%
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
df.tail()
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 81     volkswagen      sedan        97.3   171.7         ohc             four
# 82     volkswagen      sedan        97.3   171.7         ohc             four
# 86     volkswagen      sedan        97.3   171.7         ohc             four
# 87          volvo      sedan       104.3   188.8         ohc             four
# 88          volvo      wagon       104.3   188.8         ohc             four
#
#        horsepower  average-mileage    price
# index
# 81             85               27   7975.0
# 82             52               37   7995.0
# 86            100               26   9995.0
# 87            114               23  12940.0
# 88            114               23  13415.0

# %% [markdown]
# Exercise 2: Clean the dataset and update the CSV file

# %%
#to do

# %% [markdown]
# Exercise 3: Find the most expensive car company name

# %%
most_expensive_car_df = df[df['price'] == df.price.max()][['company','price']]
most_expensive_car_df
# Out:
#              company    price
# index
# 47     mercedes-benz  45400.0

# %% [markdown]
# Exercise 4: Print All Toyota Cars details

# %%
df[df['company'] == 'toyota']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66             62               35   5348.0
# 67             62               31   6338.0
# 68             62               31   6488.0
# 69             62               31   6918.0
# 70             62               27   7898.0
# 71             62               27   8778.0
# 79            156               19  15750.0

# %% [markdown]
# Exercise 5: Count total cars per company

# %%
#1. Using value counts
df['company'].value_counts().sort_values()
# Out:
# dodge            2
# volvo            2
# honda            3
# isuzu            3
# jaguar           3
# alfa-romero      3
# chevrolet        3
# porsche          3
# mercedes-benz    4
# audi             4
# mitsubishi       4
# volkswagen       4
# nissan           5
# mazda            5
# bmw              6
# toyota           7
# Name: company, dtype: int64

# %%
#2 Using group by
df.groupby(by='company').company.count().sort_values(ascending=False)
# Out:
# company
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# volkswagen       4
# mitsubishi       4
# mercedes-benz    4
# audi             4
# porsche          3
# jaguar           3
# isuzu            3
# honda            3
# chevrolet        3
# alfa-romero      3
# volvo            2
# dodge            2
# Name: company, dtype: int64

# %% [markdown]
# Exercise 6: Find each company’s Higesht price car

# %%
df.groupby('company')['company','price'].max()
# Out:
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %% [markdown]
# Exercise 7: Find the average mileage of each car making company

# %%
df.groupby('company')['company','average-mileage'].mean()
# Out:
#                average-mileage
# company
# alfa-romero          20.333333
# audi                 20.000000
# bmw                  19.000000
# chevrolet            41.000000
# dodge                31.000000
# honda                26.333333
# isuzu                33.333333
# jaguar               14.333333
# mazda                28.000000
# mercedes-benz        18.000000
# mitsubishi           29.500000
# nissan               31.400000
# porsche              17.000000
# toyota               28.714286
# volkswagen           31.750000
# volvo                23.000000

# %% [markdown]
# Exercise 8: Sort all cars by Price column

# %%
df.sort_values(by=['price','horsepower'], ascending=False).head()
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 47     mercedes-benz      hardtop       112.0   199.2        ohcv
# 14               bmw        sedan       103.5   193.8         ohc
# 46     mercedes-benz        sedan       120.9   208.1        ohcv
# 62           porsche  convertible        89.5   168.9        ohcf
# 15               bmw        sedan       110.0   197.0         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 47               eight         184               14  45400.0
# 14                 six         182               16  41315.0
# 46               eight         184               14  40960.0
# 62                 six         207               17  37028.0
# 15                 six         182               15  36880.0

# %% [markdown]
# Exercise 9: Concatenate two data frames using the following conditions`

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
german_df = pd.DataFrame(GermanCars)
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
japanese_df = pd.DataFrame(japaneseCars)
pd.concat([german_df,japanese_df], axis=0, keys=['German', 'Japan'])
# Out:
#               Company   Price
# German 0         Ford   23845
#        1     Mercedes  171995
#        2          BMV  135925
#        3         Audi   71400
# Japan  0       Toyota   29995
#        1        Honda   23600
#        2       Nissan   61500
#        3  Mitsubishi    58900

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}
car_price_df = pd.DataFrame(Car_Price)
car_horsepower_df = pd.DataFrame(car_Horsepower)

pd.concat([car_price_df, car_horsepower_df], axis=1)
# Out:
#   Company   Price Company  horsepower
# 0  Toyota   23845  Toyota         141
# 1   Honda   17995   Honda          80
# 2     BMV  135925     BMV         182
# 3    Audi   71400    Audi         160

# %%
cdf = pd.merge(car_horsepower_df,car_price_df, on='Company')
cdf
# Out:
#   Company  horsepower   Price
# 0  Toyota         141   23845
# 1   Honda          80   17995
# 2     BMV         182  135925
# 3    Audi         160   71400

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(12,6))
plt.bar(df['average-mileage'], df['price'],color='black', label='Price vs Average')
plt.plot(df['horsepower']*100)
plt.xlabel('Average')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(df['length'],label='Length')
plt.plot(df['wheel-base'],label='Wheel Base')
plt.legend()
plt.show()

# %%
group = df.company.value_counts()
group
# Out:
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# mercedes-benz    4
# audi             4
# mitsubishi       4
# volkswagen       4
# honda            3
# isuzu            3
# jaguar           3
# alfa-romero      3
# chevrolet        3
# porsche          3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
plt.pie(group.values, labels=group.index)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.imshow(df[['average-mileage','price']],cmap='hot',interpolation='nearest')

# %%
df[['price','average-mileage']]
# Out:
#          price  average-mileage
# index
# 0      13495.0               21
# 1      16500.0               21
# 2      16500.0               19
# 3      13950.0               24
# 4      17450.0               18
# 5      15250.0               19
# 6      18920.0               19
# 9      16430.0               23
# 10     16925.0               23
# 11     20970.0               21
# 13     30760.0               16
# 14     41315.0               16
# 15     36880.0               15
# 16      5151.0               47
# 17      6295.0               38
# 18      6575.0               38
# 19      6377.0               31
# 20      6229.0               31
# 27      7295.0               30
# 28     12945.0               24
# 29     10345.0               25
# 30      6785.0               24
# 31         NaN               38
# 32         NaN               38
# 33     32250.0               15
# 34     35550.0               15
# 35     36000.0               13
# 36      5195.0               30
# ...
