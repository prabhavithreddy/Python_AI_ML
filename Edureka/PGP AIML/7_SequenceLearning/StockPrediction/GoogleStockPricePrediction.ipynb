# %% [markdown]
# # Predicting Google stock prices Using RNN GRU Model
#
# This use-case provides a demo of how RNN and GRU can be used to model time series data. In our use-case, we will use 'Google stock price' data to predict the number of future stock prices based on the available historical data.
#
# Workflow:
#
#
# 1.   Understanding the problem
# 2.   Collecting the data
# 3.   Data preprocessing
# 4.   Build Model using RNN & Grated Recurrent Unit (GRU)
# 5.   Training the dataset
# 6.   Predict

# %% [markdown]
# ## 1. Understanding the problem
# You have been given a dataset that contains google stock prices. We have to model the time series data using RNN GRU sequential model.

# %% [markdown]
# Import python library

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional,SimpleRNN
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

# %%
# Some functions to help out with predictions

def rmse_return(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %% [markdown]
# ## 2. Collecting the Data
# The dataset trainset.csv will be used for the demo. The dataset contains google stock prices. The features are:
# - "Date" -  The date on which the data was collected.
# - "open" - The opening price for the specified date(s).
#
# - "close" - The closing price for the specified date(s).
#
# - "high" - The high price for the specified date(s).
#
# - "low" - The low price for the specified date(s).
#
# - "volume" - The volume for the specified date(s).
#
#
# Load the dataset using pandas read_csv function.

# %%
gsheet_url="https://docs.google.com/spreadsheets/d/1Sqf4OdzWkm_BkfnSw2YAMF_J7vEApKu3uJosyqNgPrE/edit#gid=0"

# %%
url_1 = gsheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
# First, we get the data
dataset = pd.read_csv(url_1)
dataset.head()
# Out:
#                  Date    Open    High     Low   Close   Volume
# 0  6/21/2016 16:00:00  698.40  702.77  692.01  695.94  1465634
# 1  6/22/2016 16:00:00  699.06  700.86  693.08  697.46  1184318
# 2  6/23/2016 16:00:00  697.45  701.95  687.00  701.87  2171415
# 3  6/24/2016 16:00:00  675.17  689.40  673.45  675.22  4449022
# 4  6/27/2016 16:00:00  671.00  672.30  663.28  668.26  2641085

# %%
# Converting dates:
dataset.Date = pd.to_datetime(dataset.Date)

# %%
dataset.Date=[date.strftime(format="%Y/%m/%d") for date in dataset.Date]

# %%
dataset.Date = pd.to_datetime(dataset.Date)

# %%
dataset=dataset.set_index('Date')

# %%
dataset.head()
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2016-06-21  698.40  702.77  692.01  695.94  1465634
# 2016-06-22  699.06  700.86  693.08  697.46  1184318
# 2016-06-23  697.45  701.95  687.00  701.87  2171415
# 2016-06-24  675.17  689.40  673.45  675.22  4449022
# 2016-06-27  671.00  672.30  663.28  668.26  2641085

# %%
# Checking for missing values in Training and Test set
training_set = dataset[dataset.index.year<2020].High
test_set = dataset[dataset.index.year>=2020].High

# %%
print("The dataset has information from" , dataset.index.min().strftime("%d/%m/%Y"),"to date",dataset.index.max().strftime("%d/%m/%Y"))
# Out:
# The dataset has information from 21/06/2016 to date 10/12/2021

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
dataset.head()
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2016-06-21  698.40  702.77  692.01  695.94  1465634
# 2016-06-22  699.06  700.86  693.08  697.46  1184318
# 2016-06-23  697.45  701.95  687.00  701.87  2171415
# 2016-06-24  675.17  689.40  673.45  675.22  4449022
# 2016-06-27  671.00  672.30  663.28  668.26  2641085

# %%
# Yearly standard deviation
dataset.resample('y',axis=0).agg('std')
# Out:
#                   Open        High         Low       Close         Volume
# Date
# 2016-12-31   31.091369   30.916665   30.916993   30.317360  737157.690341
# 2017-12-31   77.249509   78.340330   76.357837   77.232928  638257.185161
# 2018-12-31   67.218290   64.329414   69.119072   67.315551  716745.535941
# 2019-12-31   81.571801   81.109499   82.826251   81.765380  621731.444100
# 2020-12-31  176.792950  174.859537  178.934771  175.967843  763314.693682
# 2021-12-31  366.532090  364.868973  364.284404  364.266982  498402.797368

# %% [markdown]
# #### Yearly Candlestick

# %%
temp=dataset.copy()
temp['Date']=dataset.index

# %%
fig = go.Figure()

for year in range(int(dataset.index.min().strftime("%Y")),int(dataset.index.max().strftime("%Y"))+1):
    sample = temp[temp.Date.dt.year==year]
    fig.add_traces (go.Candlestick(x=sample.index,
                open=sample.Open,
                high=sample.High,
                low=sample.Low,
                close=sample.Close,
                visible=True,showlegend=False
                                  )
                   )
# Create menu items
items=[]
plo='Candlestick plot for '
all_plot=[True for i in range(int(dataset.index.min().strftime("%Y")),int(dataset.index.max().strftime("%Y"))+1)]
items.append(dict(label = 'All',
                    method = 'update',
                    args = [{'visible':all_plot },
                            {'title': plo+'complete data',
                            'showlegend':False}]))
ind=-1
for year in range(int(dataset.index.min().strftime("%Y")),int(dataset.index.max().strftime("%Y"))+1):
    visible_plot=[False for i in range(int(dataset.index.min().strftime("%Y")),int(dataset.index.max().strftime("%Y"))+1)]
    ind+=1
    visible_plot[ind]=True
    items.append(
            dict(label = str(year),
                    method = 'update',
                    args = [{'visible':visible_plot },
                            {'title': plo+str(year),
                            'showlegend':False}])
                )
fig.update_layout(dragmode=False,showlegend=False,template='plotly_dark',
        updatemenus=[go.layout.Updatemenu(
            active=0,
            buttons=items,
                pad={"r": 10, "t": 2},
                showactive=True,
                x=0,
                xanchor="right",
                y=1.15,
                yanchor="top"
            )
        ]
        )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e68ff5a7-d84a-474c-83ea-95e1432c0c08" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e68ff5a7-d84a-474c-83ea-95e1432c0c08")) {
#                     Plotly.newPlot(
#                         'e68ff5a7-d84a-474c-83ea-95e1432c0c08',
#                         [{"close": [695.94, 697.46, 701.87, 675.22, 668.26, 680.04, 684.11, 692.1, 699.21, 694.49, 697.77, 695.36, 705.63, 715.09, 720.64, 716.98, 720.95, 719.85, 733.78, 736.96, 741.19, 738.63, 742.74, 739.77, 738.42, 741.77, 745.91, 768.79, 772.88, 771.07, 773.18, 771.61, 782.22, 781.76, 784.26, 784.68, 784.85, 783.22, 782.44, 777.14, 779.91, 777.5, 775.42, 772.15, 772.08, 769.64, 769.41, 769.54, 772.15, 769.09, 767.05, 768.78, 771.46, 780.08, 780.35, 775.32, 759.66, 769.02, 759.69, 762.49, 771.76, 768.88, 765.7, 771.41, 776.22, 787.21, 786.9, 774.21, 783.01
760.52, 759.8, 768.24, 754.83, 737.02, 743.1, 752.9, 757.34, 755.8, 767.23, 779.02, 784.36, 793.34, 794.01, 792.92, 790.29, 786.27, 793.27, 787.1, 788.58, 787.28, 787.66, 783.2, 778.92, 770.41], "open": [698.4, 699.06, 697.45, 675.17, 671.0, 678.97, 683.0, 685.47, 692.2, 696.06, 689.98, 698.08, 699.5, 708.05, 719.12, 723.62, 721.58, 725.73, 722.71, 729.89, 737.33, 740.36, 741.86, 740.67, 739.04, 738.28, 747.04, 772.71, 761.09, 768.69, 767.18, 772.22, 773.78, 782.0, 781.1, 783.75, 785.0, 781.5, 783.75, 780.3, 777.32, 780.01, 775.0, 773.27, 775.48, 770.58, 767.0, 769.0, 768.74, 769.33, 767.01, 769.25, 773.01, 773.45, 780.0, 778.59, 770.1, 755.13, 764.48, 759.61, 762.89, 769.75, 772.42, 769.0, 772.66, 780.0, 786.59, 782.74, 775.5, 777.85, 781.44, 776.33, 774.25, 776.03, 779.31, 779.0, 779.66, 777.71, 786.66, 783.76, 781.22, 781.65, 779.8, 787.85, 798.86, 803.3, 795.0, 804.9, 816.68, 806.34, 801.0, 808.35, 795.47, 782.89, 778.2, 767.25, 750.66, 774.5,  ...

# %% [markdown]
# ### Area Chart

# %%
fig = go.Figure()
years=len(range(int(dataset.index.min().strftime("%Y")),int(dataset.index.max().strftime("%Y"))+1))

for year in range(int(dataset.index.min().strftime("%Y")),int(dataset.index.max().strftime("%Y"))+1):
    sample = temp[temp.Date.dt.year==year]
    fig.add_traces( go.Scatter(name=year,x=sample.index, y=sample.Open, fill='tozeroy',visible=True,showlegend=False)
                
            )
            

# Create menu items
items=[]
plo='Area plot for '
all_plot=[True for i in range(years)]
items.append(dict(label = 'All',
                    method = 'update',
                    args = [{'visible':all_plot },
                            {'title': plo+'complete data',
                            'showlegend':False}]))
ind=-3
for year in range(int(dataset.index.min().strftime("%Y")),int(dataset.index.max().strftime("%Y"))+1):
    visible_plot=[False for i in range(years)]
    ind+=1
    visible_plot[ind]=True
    items.append(
            dict(label = str(year),
                    method = 'update',
                    args = [{'visible':visible_plot },
                            {'title': plo+str(year),
                            'showlegend':False}])
                )
fig.update_layout(dragmode=False,showlegend=False,template='plotly',
        updatemenus=[go.layout.Updatemenu(
            active=0,
            buttons=items,
                pad={"r": 10, "t": 2},
                showactive=True,
                x=0,
                xanchor="right",
                y=1.13,
                yanchor="top"
            )
        ]
        )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c7deba73-06fd-4f79-b124-aa5e03b5d669" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c7deba73-06fd-4f79-b124-aa5e03b5d669")) {
#                     Plotly.newPlot(
#                         'c7deba73-06fd-4f79-b124-aa5e03b5d669',
#                         [{"fill": "tozeroy", "name": "2016", "showlegend": false, "type": "scatter", "visible": true, "x": ["2016-06-21T00:00:00", "2016-06-22T00:00:00", "2016-06-23T00:00:00", "2016-06-24T00:00:00", "2016-06-27T00:00:00", "2016-06-28T00:00:00", "2016-06-29T00:00:00", "2016-06-30T00:00:00", "2016-07-01T00:00:00", "2016-07-05T00:00:00", "2016-07-06T00:00:00", "2016-07-07T00:00:00", "2016-07-08T00:
12-15T00:00:00", "2016-12-16T00:00:00", "2016-12-19T00:00:00", "2016-12-20T00:00:00", "2016-12-21T00:00:00", "2016-12-22T00:00:00", "2016-12-23T00:00:00", "2016-12-27T00:00:00", "2016-12-28T00:00:00", "2016-12-29T00:00:00", "2016-12-30T00:00:00"], "y": [698.4, 699.06, 697.45, 675.17, 671.0, 678.97, 683.0, 685.47, 692.2, 696.06, 689.98, 698.08, 699.5, 708.05, 719.12, 723.62, 721.58, 725.73, 722.71, 729.89, 737.33, 740.36, 741.86, 740.67, 739.04, 738.28, 747.04, 772.71, 761.09, 768.69, 767.18, 772.22, 773.78, 782.0, 781.1, 783.75, 785.0, 781.5, 783.75, 780.3, 777.32, 780.01, 775.0, 773.27, 775.48, 770.58, 767.0, 769.0, 768.74, 769.33, 767.01, 769.25, 773.01, 773.45, 780.0, 778.59, 770.1, 755.13, 764.48, 759.61, 762.89, 769.75, 772.42, 769.0, 772.66, 780.0, 786.59, 782.74, 775.5, 777.85, 781.44, 776.33, 774.25, 776.03, 779.31, 779.0, 779.66, 777.71, 786.66, 783.76, 781.22, 781.65, 779.8, 787.85, 798.86, 803.3, 795.0, 804.9, 816.68, 806.34, 801.0, 808.35, 795.47, 782.89, 778.2, 767.25, 750.66, 774.5, 783.4, ...

# %%
# We have chosen 'High' attribute for prices. Let's see what it looks like
fig=go.Figure()
fig.add_traces( go.Scatter(x=dataset[dataset.index.year<2020].index, y=dataset[dataset.index.year<2020].Open, 
                           fill='tozeroy',
                           visible=True,
                           marker={'color':'#ff006e'},
                           showlegend=False,
                           name='Training set (Before 2020)'
                          )
                        
            )
fig.add_traces( go.Scatter(x=dataset[dataset.index.year>=2020].index, y=dataset[dataset.index.year>=2020].Open, 
                           fill='tozeroy',
                           visible=True,
                           marker={'color':'#3a86ff'},
                           showlegend=False,
                           name='Testing set (After 2020)'
                          )
            )
fig.update_layout(title='Google Stock Price Training and testing set distribution',dragmode=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bb03c959-55d0-48e7-aaa2-12126f76a4cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb03c959-55d0-48e7-aaa2-12126f76a4cd")) {
#                     Plotly.newPlot(
#                         'bb03c959-55d0-48e7-aaa2-12126f76a4cd',
#                         [{"fill": "tozeroy", "marker": {"color": "#ff006e"}, "name": "Training set (Before 2020)", "showlegend": false, "type": "scatter", "visible": true, "x": ["2016-06-21T00:00:00", "2016-06-22T00:00:00", "2016-06-23T00:00:00", "2016-06-24T00:00:00", "2016-06-27T00:00:00", "2016-06-28T00:00:00", "2016-06-29T00:00:00", "2016-06-30T00:00:00", "2016-07-01T00:00:00", "2016-07-05T00:00:00", "2016-07-06T00:00:00", "2016-07-07T00:00:00", "2016-07-08T00:00:00", "2016-07-11T00:00:00", "2016-07-12T00:00:00", "2016-07-13T00:00:00", "2016-07-14T00:00:00", "2016-07-15T00:00:00", "2016-07-18T00:00:00", "2016-07-19T00:00:00", "2016-07-20T00:00:00", "2016-07-21T00:00:00", "2016-07-22T00:00:00", "2016-07-25T00:00:00", "2016-07-26T00:00:00", "2016-07-27T00:00:00", "2016-07-28T00:00:00", "2016-07-29T00:00:00", "2016-08
"2017-01-10T00:00:00", "2017-01-11T00:00:00", "2017-01-12T00:00:00", "2017-01-13T00:00:00", "2017-01-17T00:00:00", "2017-01-18T00:00:00", "2017-01-19T00:00:00", "2017-01-20T00:00:00", "2017-01-23T00:00:00", "2017-01-24T00:00:00", "2017-01-25T00:00:00", "2017-01-26T00:00:00", "2017-01-27T00:00:00", "2017-01-30T00:00:00", "2017-01-31T00:00:00", "2017-02-01T00:00:00", "2017-02-02T00:00:00", "2017-02-03T00:00:00", "2017-02-06T00:00:00", "2017-02-07T00:00:00", "2017-02-08T00:00:00", "2017-02-09T00:00:00", "2017-02-10T00:00:00", "2017-02-13T00:00:00", "2017-02-14T00:00:00", "2017-02-15T00:00:00", "201 ...

# %%
len(training_set),len(test_set)
# Out:
# (889, 491)

# %%
# Scaling the training set
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(np.array(training_set).reshape(-1,1))

# %%
# Data Preparation
def picker(series,pos,days):
    return list(series[pos:pos+days]), series[pos+days],np.mean(np.array(series[pos:pos+days]))

def prepare_data(series,days):
    pos=0
    X,y=[],[]
    while pos!=len(series)-days:
        X_entry,y_entry,mean=picker(series,pos,days)
        X_entry= np.array(X_entry)
        X.append(X_entry);y.append(y_entry)

        pos+=1
    return np.array(X),np.array(y)

# %%
# Since RNN/GRU/LSTM store long term memory state, we create a data structure with n_days timesteps and 1 output
n_days=60
X_train,y_train=prepare_data(training_set_scaled,n_days)

# %%
# Reshaping X_train for efficient modelling
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
X_train
# Out:
# array([[[0.0439873 ],
#         [0.04122997],
#         [0.04280352],
#         ...,
#         [0.14146095],
#         [0.13558539],
#         [0.13769309]],
#
#        [[0.04122997],
#         [0.04280352],
#         [0.02468601],
#         ...,
#         [0.13558539],
#         [0.13769309],
#         [0.14652808]],
#
#        [[0.04280352],
#         [0.02468601],
#         [0.        ],
#         ...,
#         [0.13769309],
#         [0.14652808],
#         [0.14068139]],
#
#        ...,
#
#        [[0.75745633],
#         [0.74600837],
#         [0.77831673],
#         ...,
#         [0.99249314],
#         [0.97872095],
#         [0.99470189]],
#
#        [[0.74600837],
#         [0.77831673],
#         [0.78807565],
#         ...,
#         [0.97872095],
#         [0.99470189],
#         [0.9993215 ]],
#
#        [[0.77831673],
#         [0.78807565],
#         [0.77057889],
#         ...,
#         [0.99470189],
#         [0.9993215 ],
#         [0.98267648]]])

# %%
# Now to get the test set ready in a similar way as the training set.
# The following has been done for the 60 entires of test set have 60 previous values which is impossible to get unless we take the whole 
# 'High' attribute data for processing
dataset_total = dataset.copy()
inputs = dataset_total[len(dataset_total)-len(test_set) - 30:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# %% [markdown]
# ## Gated Recurrent Units
#
# In simple words, the GRU unit does not have to use a memory unit to control the flow of information like the LSTM unit. It can directly makes use of the all hidden states without any control. GRUs have fewer parameters and thus may train a bit faster or need less data to generalize. But, with large data, the LSTMs with higher expressiveness may lead to better results.
#
# They are almost similar to LSTMs except that they have two gates: reset gate and update gate. Reset gate determines how to combine new input to previous memory and update gate determines how much of the previous state to keep. Update gate in GRU is what input gate and forget gate were in LSTM. We don't have the second non linearity in GRU before calculating the outpu, .neither they have the output gate.

# %% [markdown]
# ## Create the model

# %%
# The GRU architecture
regressorGRU = Sequential()
# First GRU layer with Dropout regularisation
regressorGRU.add(SimpleRNN(50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))
# Second GRU layer
regressorGRU.add(SimpleRNN(50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))
# Third GRU layer
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))
# Fourth GRU layer
regressorGRU.add(GRU(units=50, activation='tanh'))
regressorGRU.add(Dropout(0.2))
# The output layer
regressorGRU.add(Dense(units=1))

# %%
regressorGRU.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 60, 50)            2600
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 60, 50)            5050
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  gru (GRU)                   (None, 60, 50)            15300
#
#  dropout_2 (Dropout)         (None, 60, 50)            0
#
#  gru_1 (GRU)                 (None, 50)                15300
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 38,301
# Trainable params: 38,301
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
# Compiling the GRU
regressorGRU.compile(optimizer=SGD(lr=0.01, decay=1e-7, momentum=0.9, nesterov=False),loss='mean_squared_error')
# Fitting to the training set
regressorGRU.fit(X_train,y_train,epochs=50,batch_size=150)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.
# 6/6 [==============================] - 7s 168ms/step - loss: 0.2423
# Epoch 2/50
# 6/6 [==============================] - 1s 166ms/step - loss: 0.0899
# Epoch 3/50
# 6/6 [==============================] - 1s 189ms/step - loss: 0.0461
# Epoch 4/50
# 6/6 [==============================] - 1s 185ms/step - loss: 0.0319
# Epoch 5/50
# 6/6 [==============================] - 1s 180ms/step - loss: 0.0258
# Epoch 6/50
# 6/6 [==============================] - 1s 163ms/step - loss: 0.0169
# Epoch 7/50
# 6/6 [==============================] - 1s 161ms/step - loss: 0.0140
# Epoch 8/50
# 6/6 [==============================] - 1s 171ms/step - loss: 0.0127
# Epoch 9/50
# 6/6 [==============================] - 1s 178ms/step - loss: 0.0115
# Epoch 10/50
# 6/6 [==============================] - 1s 178ms/step - loss: 0.0107
# Epoch 11/50
# 6/6 [==============================] - 1s 164ms/step - loss: 0.0097
# Epoch 12/50
# 6/6 [==============================] - 1s 170ms/step - loss: 0.0092
# Epoch 13/50
# 6/6 [==============================] - 1s 163ms/step - loss: 0.0082
# Epoch 14/50
# 6/6 [==============================] - 1s 166ms/step - loss: 0.0086
# Epoch 15/50
# 6/6 [==============================] - 1s 160ms/step - loss: 0.0075
# Epoch 16/50
# 6/6 [==============================] - 1s 163ms/step - loss: 0.0081
# Epoch 17/50
# 6/6 [==============================] - 1s 161ms/step - loss: 0.0082
# Epoch 18/50
# 6/6 [==============================] - 1s 162ms/step - loss: 0.0087
# Epoch 19/50
# 6/6 [==============================] - 1s 162ms/step - loss: 0.0074
# Epoch 20/50
# 6/6 [==============================] - 1s 182ms/step - loss: 0.0074
# Epoch 21/50
# 6/6 [==============================] - 1s 176ms/step - loss: 0.0076
# Epoch 22/50
# 6/6 [==============================] - 1s 182ms/step - loss: 0.0074
# Epoch 23/50
# 6/6 [==============================] - 1s 180ms/step - loss: 0.0075
# Epoch 24/50
# 6/6 [==============================] - 1s 174ms/step - loss: 0.0070
# Epoch 25/50
# 6/6 [==============================] - 1s 176ms/step - loss: 0.0068
# Epoch 26/50
# 6/6 [==============================] - 1s 170ms/step - loss: 0.0068
# Epoch 27/50
# 6/6 [==============================] - 1s 177ms/step - loss: 0.0069
# Epoch 28/50
# 6/6 [==============================] - 1s 179ms/step - loss: 0.0067
# Epoch 29/50
# 6/6 [==============================] - 1s 160ms/step - loss: 0.0064
# Epoch 30/50
# 6/6 [==============================] - 1s 167ms/step - loss: 0.0061
# Epoch 31/50
# 6/6 [==============================] - 1s 158ms/step - loss: 0.0071
# Epoch 32/50
# 6/6 [==============================] - 1s 159ms/step - loss: 0.0066
# Epoch 33/50
# 6/6 [==============================] - 1s 159ms/step - loss: 0.0069
# Epoch 34/50
# 6/6 [==============================] - 1s 165ms/step - loss: 0.0065
# Epoch 35/50
# 6/6 [==============================] - 1s 166ms/step - loss: 0.0059
# Epoch 36/50
# 6/6 [==============================] - 1s 171ms/step - loss: 0.0060
# Epoch 37/50
# 6/6 [==============================] - 1s 178ms/step - loss: 0.0060
# Epoch 38/50
# 6/6 [==============================] - 1s 180ms/step - loss: 0.0061
# Epoch 39/50
# 6/6 [==============================] - 1s 181ms/step - loss: 0.0061
# Epoch 40/50
# 6/6 [==============================] - 1s 165ms/step - loss: 0.0061
# Epoch 41/50
# 6/6 [==============================] - 1s 180ms/step - loss: 0.0057
# Epoch 42/50
# 6/6 [==============================] - 1s 162ms/step - loss: 0.0055
# Epoch 43/50
# 6/6 [==============================] - 1s 184ms/step - loss: 0.0052
# Epoch 44/50
# 6/6 [==============================] - 1s 178ms/step - loss: 0.0056
# Epoch 45/50
# 6/6 [==============================] - 1s 178ms/step - loss: 0.0053
# Epoch 46/50
# 6/6 [==============================] - 1s 177ms/step - loss: 0.0056
# Epoch 47/50
# 6/6 [==============================] - 1s 161ms/step - loss: 0.0064
# Epoch 48/50
# 6/6 [==============================] - 1s 161ms/step - loss: 0.0053
# Epoch 49/50
# 6/6 [==============================] - 1s 163ms/step - loss: 0.0057
# Epoch 50/50
# 6/6 [==============================] - 1s 162ms/step - loss: 0.0059

# %% [markdown]
# The current version version uses a dense GRU network with 100 units as opposed to the GRU network with 50 units in previous version

# %%
# The LSTM architecture
lstm = Sequential()
lstm.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
lstm.add(Dropout(0.2))
lstm.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=50, activation='relu'))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1))

# %%
lstm.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  dropout_4 (Dropout)         (None, 60, 50)            0
#
#  lstm_1 (LSTM)               (None, 60, 50)            20200
#
#  dropout_5 (Dropout)         (None, 60, 50)            0
#
#  lstm_2 (LSTM)               (None, 60, 50)            20200
#
#  dropout_6 (Dropout)         (None, 60, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_7 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the LSTM
lstm.compile(optimizer=SGD(lr=0.01, decay=1e-7, momentum=0.9, nesterov=False),loss='mean_squared_error')
# Fitting to the training set
lstm.fit(X_train,y_train,epochs=50,batch_size=150)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.
# 6/6 [==============================] - 8s 244ms/step - loss: 0.2593
# Epoch 2/50
# 6/6 [==============================] - 2s 263ms/step - loss: 0.0625
# Epoch 3/50
# 6/6 [==============================] - 2s 253ms/step - loss: 0.0861
# Epoch 4/50
# 6/6 [==============================] - 2s 261ms/step - loss: 0.0511
# Epoch 5/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.0533
# Epoch 6/50
# 6/6 [==============================] - 1s 248ms/step - loss: 0.0470
# Epoch 7/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.0436
# Epoch 8/50
# 6/6 [==============================] - 2s 265ms/step - loss: 0.0418
# Epoch 9/50
# 6/6 [==============================] - 2s 257ms/step - loss: 0.0392
# Epoch 10/50
# 6/6 [==============================] - 2s 264ms/step - loss: 0.0371
# Epoch 11/50
# 6/6 [==============================] - 2s 260ms/step - loss: 0.0353
# Epoch 12/50
# 6/6 [==============================] - 2s 262ms/step - loss: 0.0308
# Epoch 13/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.0273
# Epoch 14/50
# 6/6 [==============================] - 2s 245ms/step - loss: 0.0224
# Epoch 15/50
# 6/6 [==============================] - 2s 255ms/step - loss: 0.0179
# Epoch 16/50
# 6/6 [==============================] - 2s 263ms/step - loss: 0.0132
# Epoch 17/50
# 6/6 [==============================] - 2s 253ms/step - loss: 0.0102
# Epoch 18/50
# 6/6 [==============================] - 1s 245ms/step - loss: 0.0083
# Epoch 19/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.0080
# Epoch 20/50
# 6/6 [==============================] - 2s 246ms/step - loss: 0.0080
# Epoch 21/50
# 6/6 [==============================] - 1s 238ms/step - loss: 0.0080
# Epoch 22/50
# 6/6 [==============================] - 1s 238ms/step - loss: 0.0078
# Epoch 23/50
# 6/6 [==============================] - 1s 240ms/step - loss: 0.0071
# Epoch 24/50
# 6/6 [==============================] - 1s 243ms/step - loss: 0.0076
# Epoch 25/50
# 6/6 [==============================] - 2s 248ms/step - loss: 0.0075
# Epoch 26/50
# 6/6 [==============================] - 1s 238ms/step - loss: 0.0077
# Epoch 27/50
# 6/6 [==============================] - 1s 242ms/step - loss: 0.0078
# Epoch 28/50
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0076
# Epoch 29/50
# 6/6 [==============================] - 2s 263ms/step - loss: 0.0068
# Epoch 30/50
# 6/6 [==============================] - 2s 254ms/step - loss: 0.0071
# Epoch 31/50
# 6/6 [==============================] - 1s 236ms/step - loss: 0.0072
# Epoch 32/50
# 6/6 [==============================] - 1s 238ms/step - loss: 0.0069
# Epoch 33/50
# 6/6 [==============================] - 2s 253ms/step - loss: 0.0071
# Epoch 34/50
# 6/6 [==============================] - 2s 264ms/step - loss: 0.0071
# Epoch 35/50
# 6/6 [==============================] - 2s 245ms/step - loss: 0.0077
# Epoch 36/50
# 6/6 [==============================] - 2s 261ms/step - loss: 0.0068
# Epoch 37/50
# 6/6 [==============================] - 2s 241ms/step - loss: 0.0068
# Epoch 38/50
# 6/6 [==============================] - 1s 241ms/step - loss: 0.0070
# Epoch 39/50
# 6/6 [==============================] - 1s 235ms/step - loss: 0.0070
# Epoch 40/50
# 6/6 [==============================] - 1s 237ms/step - loss: 0.0070
# Epoch 41/50
# 6/6 [==============================] - 2s 257ms/step - loss: 0.0066
# Epoch 42/50
# 6/6 [==============================] - 2s 263ms/step - loss: 0.0069
# Epoch 43/50
# 6/6 [==============================] - 2s 262ms/step - loss: 0.0067
# Epoch 44/50
# 6/6 [==============================] - 2s 262ms/step - loss: 0.0072
# Epoch 45/50
# 6/6 [==============================] - 1s 240ms/step - loss: 0.0070
# Epoch 46/50
# 6/6 [==============================] - 1s 238ms/step - loss: 0.0066
# Epoch 47/50
# 6/6 [==============================] - 1s 239ms/step - loss: 0.0067
# Epoch 48/50
# 6/6 [==============================] - 1s 235ms/step - loss: 0.0064
# Epoch 49/50
# 6/6 [==============================] - 1s 247ms/step - loss: 0.0063
# Epoch 50/50
# 6/6 [==============================] - 1s 241ms/step - loss: 0.0065

# %% [markdown]
# ## Test the model

# %%
X_test,y_test=prepare_data(sc.transform(np.array(training_set[-n_days:].append(test_set)).reshape(-1,1)),n_days)

# %%
X,y=prepare_data(sc.transform(np.array(training_set.append(test_set[:n_days])).reshape(-1,1)),n_days)

# %%
# Over training set
#what are we doing?

LSTM_predicted_stock_price_train1 = lstm.predict(X.reshape(X.shape[0],X.shape[1],1))
LSTM_predicted_stock_price_train = sc.inverse_transform(LSTM_predicted_stock_price_train1)

# %%
LSTM_predicted_stock_price_train
# Out:
# array([[ 814.42596],
#        [ 814.5299 ],
#        [ 814.6017 ],
#        [ 814.64465],
#        [ 814.66473],
#        [ 814.6682 ],
#        [ 814.6631 ],
#        [ 814.66174],
#        [ 814.67316],
#        [ 814.7036 ],
#        [ 814.7579 ],
#        [ 814.8364 ],
#        [ 814.93854],
#        [ 815.05865],
#        [ 815.1923 ],
#        [ 815.33527],
#        [ 815.48346],
#        [ 815.63306],
#        [ 815.78357],
#        [ 815.9377 ],
#        [ 816.09937],
#        [ 816.2669 ],
#        [ 816.43915],
#        [ 816.6143 ],
#        [ 816.7978 ],
#        [ 817.00226],
#        [ 817.2454 ],
#        [ 817.53064],
#        [ 817.86334],
#        [ 818.2676 ],
#        [ 818.74493],
#        [ 819.285  ],
#        [ 819.88135],
#        [ 820.5159 ],
#        [ 821.16425],
#        [ 821.7939 ],
#        [ 822.36884],
#        [ 822.85565],
#        [ 823.2405 ],
#        [ 823.5255 ],
#        [ 823.7221 ],
#        [ 823.8423 ],
#        [ 823.8797 ],
#        [ 823.83246],
#        [ 823.6963 ],
#        [ 823.46674],
#        [ 823.14984],
#        [ 822.75806],
#        [ 822.30273],
#        [ 821.80304],
#        [ 821.2852 ],
#        [ 820.7534 ],
#        [ 820.2165 ],
#        [ 819.69135],
#        [ 819.18445],
#        [ 818.69586],
#        [ 818.2195 ],
#        [ 817.75183],
#        [ 817.2922 ],
#        [ 816.8437 ],
#        [ 816.413  ],
#        [ 816.01526],
#        [ 815.66534],
#        [ 815.3781 ],
#        [ 815.16986],
#        [ 815.0514 ],
#        [ 815.0274 ],
#        [ 815.1014 ],
#        [ 815.2712 ],
#        [ 815.5256 ],
#        [ 815.85406],
#        [ 816.2663 ],
#        [ 816.74854],
#        [ 817.2757 ],
#        [ 817.82056],
#        [ 818.3571 ],
#        [ 818.8687 ],
#        [ 819.34503],
#        [ 819.7817 ],
#        [ 820.1892 ],
#        [ 820.5831 ],
#        [ 820.978  ],
#        [ 821.38324],
#        [ 821.80536],
#        [ 822.248  ],
#        [ 822.71295],
#        [ 823.1972 ],
#        [ 823.6975 ],
#        [ 824.20593],
#        [ 824.7269 ],
#        [ 825.27   ],
#        [ 825.84894],
#        [ 826.47705],
#        [ 827.172  ],
#        [ 827.9242 ],
#        [ 828.7057 ],
#        [ 829.4832 ],
#        [ 830.2247 ],
#        [ 830.9056 ],
#        [ 831.5088 ],
#        [ 832.0298 ],
#        [ 832.46936],
#        [ 832.8365 ],
#        [ 833.13763],
#        [ 833.3876 ],
#        [ 833.6049 ],
#        [ 833.80554],
#        [ 834.0041 ],
#        [ 834.2153 ],
#        [ 834.45123],
#        [ 834.7251 ],
#        [ 835.04236],
#        [ 835.4009 ],
#        [ 835.7993 ],
#        [ 836.2316 ],
#        [ 836.6951 ],
#        [ 837.18506],
#        [ 837.6929 ],
#        [ 838.21014],
#        [ 838.7303 ],
#        [ 839.2507 ],
#        [ 839.77264],
#        [ 840.30255],
#        [ 840.8457 ],
#        [ 841.40924],
#        [ 841.9961 ],
#        [ 842.6089 ],
#        [ 843.2495 ],
#        [ 843.91547],
#        [ 844.6049 ],
#        [ 845.3023 ],
#        [ 845.97864],
#        [ 846.603  ],
#        [ 847.1505 ],
#        [ 847.6052 ],
#        [ 847.9628 ],
#        [ 848.22675],
#        [ 848.4056 ],
#        [ 848.5153 ],
#        [ 848.5689 ],
#        [ 848.58575],
#        [ 848.57904],
#        [ 848.5529 ],
#        [ 848.5079 ],
#        [ 848.442  ],
#        [ 848.3538 ],
#        [ 848.24084],
#        [ 848.1092 ],
#        [ 847.9706 ],
#        [ 847.83594],
#        [ 847.7211 ],
#        [ 847.6366 ],
#        [ 847.6047 ],
#        [ 847.6533 ],
#        [ 847.81226],
#        [ 848.0977 ],
#        [ 848.5443 ],
#        [ 849.18616],
#        [ 850.0498 ],
#        [ 851.1463 ],
#        [ 852.48615],
#        [ 854.1426 ],
#        [ 856.14404],
#        [ 858.449  ],
#        [ 861.0502 ],
#        [ 863.9122 ],
#        [ 866.96344],
#        [ 870.1439 ],
#        [ 873.42444],
#        [ 876.86646],
#        [ 880.3745 ],
#        [ 883.8913 ],
#        [ 887.4553 ],
#        [ 891.0812 ],
#        [ 894.7039 ],
#        [ 898.3027 ],
#        [ 901.8836 ],
#        [ 905.45776],
#        [ 909.0368 ],
#        [ 912.61505],
#        [ 916.2479 ],
#        [ 919.97705],
#        [ 923.79114],
#        [ 927.6679 ],
#        [ 931.5799 ],
#        [ 935.49396],
#        [ 939.326  ],
#        [ 942.9946 ],
#        [ 946.4313 ],
#        [ 949.55457],
#        [ 952.3073 ],
#        [ 954.6696 ],
#        [ 956.6509 ],
#        [ 958.28546],
#        [ 959.6086 ],
#        [ 960.6659 ],
#        [ 961.5186 ],
#        [ 962.191  ],
#        [ 962.6784 ],
#        [ 962.9605 ],
#        [ 962.99805],
#        [ 962.7488 ],
#        [ 962.17584],
#        [ 961.2581 ],
#        [ 960.00684],
#        [ 958.4649 ],
#        [ 956.693  ],
#        [ 954.77496],
#        [ 952.8171 ],
#        [ 950.91907],
#        [ 949.17145],
#        [ 947.66187],
#        [ 946.45166],
#        [ 945.59357],
#        [ 945.114  ],
#        [ 945.03235],
#        [ 945.30457],
#        [ 945.8783 ],
#        [ 946.6697 ],
#        [ 947.58466],
#        [ 948.53467],
#        [ 949.4396 ],
#        [ 950.22327],
#        [ 950.828  ],
#        [ 951.2139 ],
#        [ 951.3582 ],
#        [ 951.2632 ],
#        [ 950.9313 ],
#        [ 950.36206],
#        [ 949.55963],
#        [ 948.5426 ],
#        [ 947.33936],
#        [ 945.99713],
#        [ 944.557  ],
#        [ 943.04205],
#        [ 941.4567 ],
#        [ 939.82935],
#        [ 938.1952 ],
#        [ 936.5919 ],
#        [ 935.0496 ],
#        [ 933.574  ],
#        [ 932.16974],
#        [ 930.8545 ],
#        [ 929.6818 ],
#        [ 928.6775 ],
#        [ 927.8516 ],
#        [ 927.2053 ],
#        [ 926.7148 ],
#        [ 926.3711 ],
#        [ 926.16705],
#        [ 926.0788 ],
#        [ 926.08484],
#        [ 926.17175],
#        [ 926.31885],
#        [ 926.48566],
#        [ 926.63403],
#        [ 926.75037],
#        [ 926.84674],
#        [ 926.92584],
#        [ 926.98663],
#        [ 927.02704],
#        [ 927.0777 ],
#        [ 927.1731 ],
#        [ 927.36163],
#        [ 927.6886 ],
#        [ 928.1826 ],
#        [ 928.8618 ],
#        [ 929.74   ],
#        [ 930.84186],
#        [ 932.19275],
#        [ 933.79974],
#        [ 935.66675],
#        [ 937.79456],
#        [ 940.1776 ],
#        [ 942.7965 ],
#        [ 945.6177 ],
#        [ 948.61694],
#        [ 951.7359 ],
#        [ 954.9204 ],
#        [ 958.11804],
#        [ 961.2596 ],
#        [ 964.2768 ],
#        [ 967.1159 ],
#        [1077.3888 ],
#        [1076.7527 ],
#        [1076.3817 ],
#        [1076.356  ],
#        [1076.7056 ],
#        [1077.421  ],
#        [1078.4624 ],
#        [1079.7616 ],
#        [1081.2515 ],
#        [1082.8738 ],
#        [1084.5769 ],
#        [1086.3127 ],
#        [1088.0391 ],
#        [1089.7125 ],
#        [1091.2753 ],
#        [1092.7301 ],
#        [1094.1274 ],
#        [1095.562  ],
#        [1097.1318 ],
#        [1098.904  ],
#        [1100.9121 ],
#        [1103.1598 ],
#        [1105.6263 ],
#        [1108.2911 ],
#        [1111.1396 ],
#        [1114.0789 ],
#        [1117.0881 ],
#        [1120.1917 ],
#        [1123.3973 ],
#        [1126.7156 ],
#        [1130.1447 ],
#        [1133.6471 ],
#        [1137.1178 ],
#        [1140.4702 ],
#        [1143.5818 ],
#        [1146.3674 ],
#        [1148.7928 ],
#        [1150.8494 ],
#        [1152.5448 ],
#        [1153.8998 ],
#        [1154.9539 ],
#        [1155.7675 ],
#        [1156.4141 ],
#        [1156.9672 ],
#        [1157.5032 ],
#        [1158.1135 ],
#        [1158.857  ],
#        [1159.787  ],
#        [1160.936  ],
#        [1162.3114 ],
#        [1163.889  ],
#        [1165.6377 ],
#        [1167.599  ],
#        [1169.8208 ],
#        [1172.3335 ],
#        [1175.1499 ],
#        [1178.2208 ],
#        [1181.4542 ],
#        [1184.7615 ],
#        [1188.0597 ],
#        [1191.273  ],
#        [1194.342  ],
#        [1197.2482 ],
#        [1199.9955 ],
#        [1202.6006 ],
#        [1205.0638 ],
#        [1207.3822 ],
#        [1209.5453 ],
#        [1211.5245 ],
#        [1213.3091 ],
#        [1214.8661 ],
#        [1216.1716 ],
#        [1217.2202 ],
#        [1218.016  ],
#        [1218.5791 ],
#        [1218.9355 ],
#        [1219.1398 ],
#        [1219.2479 ],
#        [1219.3188 ],
#        [1219.4028 ],
#        [1219.5232 ],
#        [1219.6624 ],
#        [1219.7742 ],
#        [1219.8015 ],
#        [1219.6824 ],
#        [1219.3671 ],
#        [1218.8333 ],
#        [1218.0754 ],
#        [1217.1095 ],
#        [1215.9326 ],
#        [1214.5771 ],
#        [1213.0784 ],
#        [1211.4694 ],
#        [1209.7917 ],
#        [1208.1001 ],
#        [1206.4315 ],
#        [1204.8169 ],
#        [1203.2906 ],
#        [1201.889  ],
#        [1200.637  ],
#        [1199.5581 ],
#        [1198.673  ],
#        [1197.9889 ],
#        [1197.4912 ],
#        [1197.1278 ],
#        [1196.8354 ],
#        [1196.5405 ],
#        [1196.1522 ],
#        [1195.5675 ],
#        [1194.7108 ],
#        [1193.5377 ],
#        [1192.0457 ],
#        [1190.2615 ],
#        [1188.2347 ],
#        [1185.9993 ],
#        [1183.592  ],
#        [1181.0518 ],
#        [1178.4067 ],
#        [1175.6941 ],
#        [1172.9492 ],
#        [1170.1925 ],
#        [1167.3716 ],
#        [1164.4784 ],
#        [1161.5283 ],
#        [1158.5388 ],
#        [1155.4988 ],
#        [1152.395  ],
#        [1149.234  ],
#        [1146.0928 ],
#        [1143.0175 ],
#        [1140.0151 ],
#        [1137.0615 ],
#        [1196.5659 ],
#        [1194.4015 ],
#        [1192.21   ],
#        [1189.963  ],
#        [1187.5867 ],
#        [1184.9963 ],
#        [1182.1213 ],
#        [1178.9193 ],
#        [1175.4073 ],
#        [1171.6592 ],
#        [1167.7815 ],
#        [1163.8607 ],
#        [1159.9794 ],
#        [1156.1921 ],
#        [1152.5271 ],
#        [1149.048  ],
#        [1145.8319 ],
#        [1142.9379 ],
#        [1140.4104 ],
#        [1138.2686 ],
#        [1136.4982 ],
#        [1135.042  ],
#        [1133.8246 ],
#        [1132.7708 ],
#        [1131.8457 ],
#        [1131.0378 ],
#        [1130.3667 ],
#        [1129.8652 ],
#        [1129.5537 ],
#        [1129.443  ],
#        [1129.55   ],
#        [1129.9025 ],
#        [1130.5116 ],
#        [1131.3773 ],
#        [1132.4998 ],
#        [1133.867  ],
#        [1135.4243 ],
#        [1137.14   ],
#        [1138.9554 ],
#        [1140.8162 ],
#        [1142.6724 ],
#        [1144.5046 ],
#        [1146.3635 ],
#        [1148.3837 ],
#        [1150.6511 ],
#        [1153.214  ],
#        [1156.0803 ],
#        [1159.2002 ],
#        [1162.4606 ],
#        [1165.7228 ],
#        [1168.8848 ],
#        [1171.8894 ],
#        [1174.7052 ],
#        [1177.3052 ],
#        [1179.6903 ],
#        [1181.8506 ],
#        [1183.7599 ],
#        [1185.4111 ],
#        [1186.8368 ],
#        [1188.0662 ],
#        [1189.1326 ],
#        [1190.0684 ],
#        [1190.8912 ],
#        [1191.5907 ],
#        [1192.1641 ],
#        [1192.5999 ],
#        [1192.9159 ],
#        [1193.1438 ],
#        [1193.3    ],
#        [1193.3945 ],
#        [1193.4662 ],
#        [1193.5594 ],
#        [1193.7123 ],
#        [1193.9495 ],
#        [1194.2914 ],
#        [1194.7706 ],
#        [1195.4175 ],
#        [1196.2411 ],
#        [1197.2352 ],
#        [1198.3811 ],
#        [1199.6616 ],
#        [1201.0575 ],
#        [1202.5386 ],
#        [1204.082  ],
#        [1205.6654 ],
#        [1207.2694 ],
#        [1208.8656 ],
#        [1210.4185 ],
#        [1211.874  ],
#        [1213.1785 ],
#        [1214.2721 ],
#        [1215.1313 ],
#        [1215.7639 ],
#        [1216.1785 ],
#        [1216.3918 ],
#        [1216.4333 ],
#        [1216.3495 ],
#        [1216.1843 ],
#        [1215.999  ],
#        [1215.8538 ],
#        [1215.8087 ],
#        [1215.9032 ],
#        [1216.1406 ],
#        [1216.5322 ],
#        [1217.0682 ],
#        [1217.7385 ],
#        [1218.5355 ],
#        [1219.475  ],
#        [1220.5564 ],
#        [1221.7532 ],
#        [1223.0314 ],
#        [1224.3572 ],
#        [1225.7245 ],
#        [1227.1365 ],
#        [1228.586  ],
#        [1230.0963 ],
#        [1231.6794 ],
#        [1233.3282 ],
#        [1235.0265 ],
#        [1236.7535 ],
#        [1238.4913 ],
#        [1240.227  ],
#        [1241.964  ],
#        [1243.7025 ],
#        [1245.4205 ],
#        [1247.0941 ],
#        [1248.6921 ],
#        [1250.1941 ],
#        [1251.5885 ],
#        [1252.8715 ],
#        [1254.0363 ],
#        [1255.0801 ],
#        [1255.9922 ],
#        [1256.7894 ],
#        [1257.4966 ],
#        [1258.1523 ],
#        [1258.8077 ],
#        [1259.4967 ],
#        [1260.2397 ],
#        [1261.0486 ],
#        [1261.9231 ],
#        [1262.8656 ],
#        [1263.8748 ],
#        [1264.9392 ],
#        [1266.0424 ],
#        [1267.1693 ],
#        [1268.3029 ],
#        [1269.4197 ],
#        [1270.5028 ],
#        [1271.548  ],
#        [1272.5408 ],
#        [1273.4553 ],
#        [1274.2932 ],
#        [1275.0701 ],
#        [1275.8192 ],
#        [1276.5807 ],
#        [1277.3923 ],
#        [1278.2942 ],
#        [1279.3163 ],
#        [1280.4806 ],
#        [1281.794  ],
#        [1283.2493 ],
#        [1284.8346 ],
#        [1286.5521 ],
#        [1288.4072 ],
#        [1290.406  ],
#        [1292.539  ],
#        [1294.7815 ],
#        [1297.0688 ],
#        [1299.3279 ],
#        [1301.5079 ],
#        [1303.5704 ],
#        [1305.4958 ],
#        [1307.2909 ],
#        [1308.9576 ],
#        [1310.49   ],
#        [1311.8983 ],
#        [1313.1975 ],
#        [1314.4164 ],
#        [1315.5981 ],
#        [1316.7733 ],
#        [1317.9641 ],
#        [1319.1792 ],
#        [1320.4229 ],
#        [1321.6936 ],
#        [1322.9828 ],
#        [1324.2676 ],
#        [1325.4761 ],
#        [1326.533  ],
#        [1327.3656 ],
#        [1327.8948 ],
#        [1328.041  ],
#        [1327.7855 ],
#        [1327.1598 ],
#        [1326.2094 ],
#        [1324.9644 ],
#        [1323.418  ],
#        [1321.525  ],
#        [1319.2643 ],
#        [1316.6285 ],
#        [1313.5801 ],
#        [1310.1107 ],
#        [1306.1842 ],
#        [1301.7542 ],
#        [1296.7883 ],
#        [1291.3282 ],
#        [1285.4467 ],
#        [1279.1677 ],
#        [1272.5696 ],
#        [1265.7456 ],
#        [1258.783  ]], dtype=float32)

# %%
# Over training set
GRU_predicted_stock_price_train = regressorGRU.predict(X.reshape(X.shape[0],X.shape[1],1))
GRU_predicted_stock_price_trainb = sc.inverse_transform(GRU_predicted_stock_price_train)

# %%
# Over test set
LSTM_predicted_stock_price = lstm.predict(X_test.reshape(X_test.shape[0],X_test.shape[1],1))
LSTM_predicted_stock_price_test = sc.inverse_transform(LSTM_predicted_stock_price)

# %%
# Over test set
GRU_predicted_stock_price = regressorGRU.predict(X_test.reshape(X_test.shape[0],X_test.shape[1],1))
GRU_predicted_stock_price_test = sc.inverse_transform(GRU_predicted_stock_price)

# %%
# We have chosen 'High' attribute for prices. Let's see what it looks like
fig=go.Figure()
fig.add_traces( go.Scatter(x=dataset[dataset.index.year<2020].index, y=dataset[dataset.index.year<2020].Open, 

                           visible=True,
                           marker={'color':'#ff006e'},
                           showlegend=True,
                           name='Training set (Before 2020)'
                          )
                        
            )
fig.add_traces( go.Scatter(x=dataset[dataset.index.year>=2020].index, y=dataset[dataset.index.year>=2020].Open, 

                           visible=True,
                           marker={'color':'#3a86ff'},
                           showlegend=True,
                           name='Testing set (After 2020)'
                          )
              )

fig.add_traces( go.Scatter(x=dataset[dataset.index.year>=2020].index, y=[i[0] for i in LSTM_predicted_stock_price_test],

                           visible=True,
                           marker={'color':'#007f5f'},
                           showlegend=True,
                           name='Predicted'
                          )
            )

fig.add_traces( go.Scatter(x=dataset[dataset.index.year<2020].index, y=[i[0] for i in LSTM_predicted_stock_price_train],

                           visible=True,
                           marker={'color':'#007f5f'},
                           showlegend=False,
                           name='Predicted'
                          )
            )

fig.add_traces( go.Scatter(x=dataset[dataset.index.year>=2020].index, y=[i[0] for i in GRU_predicted_stock_price_test],
                            
                           visible=True,
                           marker={'color':'#fbc4ab'},
                           showlegend=True,
                           name='Predicted'
                          )
            )

fig.add_traces( go.Scatter(x=dataset[dataset.index.year<2020].index, y=[i[0] for i in GRU_predicted_stock_price_train],

                           visible=True,
                           marker={'color':'#fbc4ab'},
                           showlegend=False,
                           name='Predicted'
                          )
            )
fig.update_layout(title='Google Stock Price Prediction LSTM',dragmode=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="aaef2d11-7bc1-4182-a0ef-42d55931aae9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aaef2d11-7bc1-4182-a0ef-42d55931aae9")) {
#                     Plotly.newPlot(
#                         'aaef2d11-7bc1-4182-a0ef-42d55931aae9',
#                         [{"marker": {"color": "#ff006e"}, "name": "Training set (Before 2020)", "showlegend": true, "type": "scatter", "visible": true, "x": ["2016-06-21T00:00:00", "2016-06-22T00:00:00", "2016-06-23T00:00:00", "2016-06-24T00:00:00", "2016-06-27T00:00:00", "2016-06-28T00:00:00", "2016-06-29T00:00:00", "2016-06-30T00:00:00", "2016-07-01T00:00:00", "2016-07-05T00:00:00", "2016-07-06T00:00:00", "2016-07-07T00:00:00", "2016-07-08T00:00:00", "2016-07-11T00:00:00", "2016-07-12T00:00:00", "2016-07-13T00:00:00", "2016-07-14T00:00:00", "2016-07-15T00:00:00", "2016-07-18T00:00:00", "2016-07-19T00:00:00", "2016-07-20T00:00:00", "2016-07-21T00:00:00", "2016-07-22T00:00:00", "2016-07-25T00:00:00", "2016-07-26T00:00:00", "2016-07-27T00:00:00", "2016-07-28T00:00:00", "2016-07-29T00:00:00", "2016-08-01T00:00:00", "2016-08-02T00:00:00", "2016-08-03T00:00:00", "2016-08-04T00:00:00", "2016-08-05T00:00:00", "2016-08-08T00:00:00", "2016-08-09T00:00:00", "2016-08-10T00:00:00", "2016-08-11T00:00:00", "2016-08-12T00:00:00", "2016-08-15T00:00:00", "2016-08-16T00:00:00", "2016-08-17T00:00:00", "2016-08-18T00:00:00", "2016-08-19T00:00:00", "2016-08-22T00:00:00", "2016-08-23T00:00:00", "2016-08-24T00:00:00", "2016-08-25T00:00:00", "2016-08-26T00:00:00", "2016-08-29T00:00:00", "2016-08-30T00:00:00", "2016-08-31T00:00:00", "2016-09-01T00:00:00", "2016-09-02T00:00:00", "2016-09-06T00:00:00", "2016-09-07T00:00:00", "2016-09-08T00:00:00", "2016-09-09T00:00:00", "2016-09-12T00:00:00", "2016-09-13T00:00:00", "2016-09-14T00:00:00", "2016-09-15T00:00:00", "2016-09-16T00:00:00", "2016-09-19T00:00:00", "2016-09-20T00:00:00", "2016-09-21T00:00:00", "2016-09-22T00:00:00", "2016-09-23T00:00:00