# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import sidetable as stb
import warnings
warnings.filterwarnings('ignore')

# %%
age_group_df = pd.read_csv('AgeGroupDetails.csv', index_col=[0])
age_group_df.head()
# Out:
#     AgeGroup  TotalCases Percentage
# Sno
# 1        0-9          22      3.18%
# 2      10-19          27      3.90%
# 3      20-29         172     24.86%
# 4      30-39         146     21.10%
# 5      40-49         112     16.18%

# %%
df = pd.read_csv('covid_19_india.csv', index_col=[0])
df.head()
# Out:
#          Date     Time State/UnionTerritory ConfirmedIndianNational  \
# Sno
# 1    30/01/20  6:00 PM               Kerala                       1
# 2    31/01/20  6:00 PM               Kerala                       1
# 3    01/02/20  6:00 PM               Kerala                       2
# 4    02/02/20  6:00 PM               Kerala                       3
# 5    03/02/20  6:00 PM               Kerala                       3
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# Sno
# 1                          0      0       0          1
# 2                          0      0       0          1
# 3                          0      0       0          2
# 4                          0      0       0          3
# 5                          0      0       0          3

# %%
hospital_beds_df = pd.read_csv('HospitalBedsIndia.csv')
df.head()
# Out:
#          Date     Time State/UnionTerritory ConfirmedIndianNational  \
# Sno
# 1    30/01/20  6:00 PM               Kerala                       1
# 2    31/01/20  6:00 PM               Kerala                       1
# 3    01/02/20  6:00 PM               Kerala                       2
# 4    02/02/20  6:00 PM               Kerala                       3
# 5    03/02/20  6:00 PM               Kerala                       3
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# Sno
# 1                          0      0       0          1
# 2                          0      0       0          1
# 3                          0      0       0          2
# 4                          0      0       0          3
# 5                          0      0       0          3

# %%
population_df = pd.read_csv('datasets_507962_1091873_population_by_country_2020.csv')
df.head()
# Out:
#          Date     Time State/UnionTerritory ConfirmedIndianNational  \
# Sno
# 1    30/01/20  6:00 PM               Kerala                       1
# 2    31/01/20  6:00 PM               Kerala                       1
# 3    01/02/20  6:00 PM               Kerala                       2
# 4    02/02/20  6:00 PM               Kerala                       3
# 5    03/02/20  6:00 PM               Kerala                       3
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# Sno
# 1                          0      0       0          1
# 2                          0      0       0          1
# 3                          0      0       0          2
# 4                          0      0       0          3
# 5                          0      0       0          3

# %%
confirmed_df = pd.read_csv('time_series_covid_19_confirmed_global.csv')
confirmed_df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/26/21  6/27/21  6/28/21  \
# 0        0        0        0        0  ...   111592   111592   115751
# 1        0        0        0        0  ...   132509   132512   132513
# 2        0        0        0        0  ...   138113   138465   138840
# 3        0        0        0        0  ...    13882    13882    13882
# 4        0        0        0        0  ...    38528    38556    38613
#
#    6/29/21  6/30/21  7/1/21  7/2/21  7/3/21  7/4/21  7/5/21
# ...

# %%
deaths_df = pd.read_csv('time_series_covid_19_deaths_global.csv')
deaths_df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/26/21  6/27/21  6/28/21  \
# 0        0        0        0        0  ...     4519     4519     4730
# 1        0        0        0        0  ...     2456     2456     2456
# 2        0        0        0        0  ...     3685     3693     3699
# 3        0        0        0        0  ...      127      127      127
# 4        0        0        0        0  ...      887      889      891
#
#    6/29/21  6/30/21  7/1/21  7/2/21  7/3/21  7/4/21  7/5/21
# ...

# %%
recovered_df = pd.read_csv('time_series_covid_19_recovered_global.csv')
recovered_df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/26/21  6/27/21  6/28/21  \
# 0        0        0        0        0  ...    67483    68288    69205
# 1        0        0        0        0  ...   129982   129990   129994
# 2        0        0        0        0  ...    96108    96335    96572
# 3        0        0        0        0  ...    13697    13697    13697
# 4        0        0        0        0  ...    32696    32791    32819
#
#    6/29/21  6/30/21  7/1/21  7/2/21  7/3/21  7/4/21  7/5/21
# ...

# %% [markdown]
# ### Question-1: Visualize Active, Recovering, and Deaths in Hotspot Countries and write down the inference

# %%
numerical_cols = confirmed_df.select_dtypes(exclude='object').columns
numerical_cols = numerical_cols.drop(['Lat', 'Long'])
numerical_cols.shape
# Out:
# (531,)

# %%
import matplotlib.dates as mdates
hotspots = ['China','Germany','Iran','Italy','Spain','US','Korea, South','France','Turkey','United Kingdom','India']

# %%
dates = confirmed_df.columns[4:].tolist()
dates = list(pd.to_datetime(dates))
dates_india = dates[8:]

df1 = confirmed_df.groupby('Country/Region').sum().reset_index()
df2 = deaths_df.groupby('Country/Region').sum().reset_index()
df3 = recovered_df.groupby('Country/Region').sum().reset_index()

global_confirmed = {}
global_deaths = {}
global_recovered = {}
global_active = {}

for country in hotspots:
    k = df1[df1['Country/Region'] == country].loc[:, '1/30/20':]
    global_confirmed[country] = k.values.tolist()[0]
    
    k = df2[df2['Country/Region'] == country].loc[:, '1/30/20':]
    global_deaths[country] = k.values.tolist()[0]
    
    k = df3[df3['Country/Region'] == country].loc[:, '1/30/20':]
    global_recovered[country] = k.values.tolist()[0]
    
for country in hotspots:
    k = list(map(int.__sub__, global_confirmed[country], global_deaths[country]))
    global_active[country] = list(map(int.__sub__, k, global_recovered[country]))
    
fig = plt.figure(figsize=(15,15))
plt.suptitle('Active, Recovered, Deaths in Hotspot Countries', fontsize = 20, y=1.0)
k=0
for i in range(1,12):
    ax = fig.add_subplot(6,2,i)
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%b'))
    ax.bar(dates_india,global_active[hotspots[k]],color='green', alpha=0.6, label='Active')
    ax.bar(dates_india,global_recovered[hotspots[k]],color='blue', alpha=0.6, label='Recovered')
    ax.bar(dates_india,global_active[hotspots[k]],color='red', alpha=0.6, label='Death')
    plt.title(hotspots[k])
    handles, labels = ax.get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper left')
    k+=1
plt.tight_layout(pad=3.0)

# %% [markdown]
# ### Question-2: Visualize COVID-19 trend in India

# %%
confirmed_df[confirmed_df['Country/Region'] == 'India']
# Out:
# (1, 535)

# %%
india_confirmed_df = confirmed_df[confirmed_df['Country/Region'] == 'India'].iloc[:, 4:]
india_confirmed_df.head()
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  \
# 147        0        0        0        0        0        0        0        0
#
#      1/30/20  1/31/20  ...   6/26/21   6/27/21   6/28/21   6/29/21   6/30/21  \
# 147        1        1  ...  30233183  30279331  30316897  30362848  30411634
#
#        7/1/21    7/2/21    7/3/21    7/4/21    7/5/21
# 147  30458251  30502362  30545433  30585229  30619932
#
# [1 rows x 531 columns]

# %%
dates = list(confirmed_df.columns[4:])
dates = list(pd.to_datetime(dates))
dates_india = dates[8:]

df1 = confirmed_df.groupby('Country/Region').sum().reset_index()
df2 = deaths_df.groupby('Country/Region').sum().reset_index()
df3 = recovered_df.groupby('Country/Region').sum().reset_index()

k = df1[df1['Country/Region'] == 'India'].loc[:, '1/30/20':]
india_confirmed = k.values.tolist()[0]

k = df2[df2['Country/Region'] == 'India'].loc[:, '1/30/20':]
india_deaths = k.values.tolist()[0]

k = df3[df3['Country/Region'] == 'India'].loc[:, '1/30/20':]
india_recovered = k.values.tolist()[0]

plt.figure(figsize= (15,10))
plt.xticks(rotation = 90, fontsize=11)
plt.yticks(fontsize = 10)
plt.xlabel("Dates", fontsize=20)
plt.ylabel('Total cases', fontsize=20)
plt.title('Total Confirmed, Recovered, Deaths in India', fontsize=25)
ax1 = plt.plot_date(y=india_confirmed, x=dates_india, label='Confirmed', linestyle = '-', color='b')
ax2 = plt.plot_date(y=india_recovered, x=dates_india, label='Recovered', linestyle = '-', color='g')
ax3 = plt.plot_date(y=india_deaths, x=dates_india, label='Death', linestyle = '-', color='r')
plt.legend()

# %% [markdown]
# ### Question-4: People of which age are affected the most? Visualize the same with different age group and write down the inference

# %%
age_group_df.head()
# Out:
#     AgeGroup  TotalCases Percentage
# Sno
# 1        0-9          22      3.18%
# 2      10-19          27      3.90%
# 3      20-29         172     24.86%
# 4      30-39         146     21.10%
# 5      40-49         112     16.18%

# %%
plt.figure(figsize=(15,10))
plt.pie(x='TotalCases',
        data=age_group_df, 
        labels=age_group_df['AgeGroup'], 
        autopct="%1.1f%%", 
        explode = [0.05 for c in age_group_df['AgeGroup']],
       startangle=9)
center_circle = plt.Circle((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(center_circle)
plt.title('India - Age Group wise Distribution',fontsize = 20)
plt.axis('equal') 
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Question-5: Create a color map to represent the LIVE status of COVID-19 in all the states of INDIA
