# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('top50.csv',index_col=[0])
df.head()
# Out:
#      Artist.Name           Genre  Beats.Per.Minute  Energy  Danceability  \
# 1   Shawn Mendes    canadian pop               117      55            76
# 2       Anuel AA  reggaeton flow               105      81            79
# 3  Ariana Grande       dance pop               190      80            40
# 4     Ed Sheeran             pop                93      65            64
# 5    Post Malone         dfw rap               150      65            58
#
#    Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 1              -6         8        75      191               4             3
# 2              -4         8        61      302               8             9
# 3              -4        16        70      186              12            46
# 4              -8         8        55      198              12            19
# 5              -4        11        18      175              45             7
#
#    Popularity
# 1          79
# 2          92
# 3          85
# 4          86
# 5          94

# %% [markdown]
# ### 11. Find the total length of songs, group by genre from top to bottom.

# %%
df.groupby('Genre')['Length.'].sum().sort_values(ascending=False)
# Out:
# Genre
# dance pop           1621
# pop                 1368
# latin               1126
# edm                  656
# reggaeton flow       611
# canadian hip hop     579
# panamanian pop       514
# reggaeton            427
# brostep              396
# electropop           389
# canadian pop         382
# dfw rap              333
# country rap          272
# australian pop       210
# atl hip hop          200
# boy band             181
# escape room          173
# big room             164
# r&b en espanol       162
# pop house            153
# trap music           131
# Name: Length., dtype: int64

# %% [markdown]
# ### 12. Print the artist name with the most number of tracks in one genre.

# %%
df.head(1)
# Out:
#     Artist.Name         Genre  Beats.Per.Minute  Energy  Danceability  \
# 1  Shawn Mendes  canadian pop               117      55            76
#
#    Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 1              -6         8        75      191               4             3
#
#    Popularity
# 1          79

# %%
result = df.groupby(['Genre','Artist.Name'])['Artist.Name'].count().sort_values(ascending=False).head(1)
result
# Out:
# Genre  Artist.Name
# pop    Ed Sheeran     4
# Name: Artist.Name, dtype: int64

# %%
# Out:
# 'Ed Sheeran'

# %% [markdown]
# ### 13. Print the data of the tracks created by the artist from the previous question.

# %%
filter = (df['Genre']==result.index[0][0]) & (df['Artist.Name']==result.index[0][1])

# %%
df[filter]
# Out:
#    Artist.Name Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# 4   Ed Sheeran   pop                93      65            64              -8
# 6   Ed Sheeran   pop               102      68            80              -5
# 38  Ed Sheeran   pop               152      82            72              -5
# 50  Ed Sheeran   pop                95      79            75              -6
#
#     Liveness  Valence.  Length.  Acousticness..  Speechiness.  Popularity
# 4          8        55      198              12            19          86
# 6          9        84      220               9             4          84
# 38        36        91      162              13             5          87
# 50         7        61      206              21            12          82

# %% [markdown]
# ### 14. Create a new column called Rating and inputs data as:
#     If popularity is greater than average set as 'Good'
#     If popularity is less than average set as 'Bad'

# %%
df['Popularity'].mean()
# Out:
# 87.5

# %%
df['Rating'] = df['Popularity'].map(lambda x: 'Good' if x > df['Popularity'].mean() else 'Bad' )
df.head()
# Out:
#      Artist.Name           Genre  Beats.Per.Minute  Energy  Danceability  \
# 1   Shawn Mendes    canadian pop               117      55            76
# 2       Anuel AA  reggaeton flow               105      81            79
# 3  Ariana Grande       dance pop               190      80            40
# 4     Ed Sheeran             pop                93      65            64
# 5    Post Malone         dfw rap               150      65            58
#
#    Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 1              -6         8        75      191               4             3
# 2              -4         8        61      302               8             9
# 3              -4        16        70      186              12            46
# 4              -8         8        55      198              12            19
# 5              -4        11        18      175              45             7
#
#    Popularity Rating
# 1          79    Bad
# 2          92   Good
# 3          85    Bad
# 4          86    Bad
# 5          94   Good

# %% [markdown]
# ### 15. Plot the average length of every genre on a horizontal bar chart.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')

# %%
sns.barplot('Length.','Genre',data=df)
# Out:
# <AxesSubplot:xlabel='Length.', ylabel='Genre'>

# %% [markdown]
# ### 16. Plot a pie chart of ratings and display the labels.

# %%
result = df.groupby('Rating')['Rating'].count()
result
# Out:
# Rating
# Bad     18
# Good    32
# Name: Rating, dtype: int64

# %%
plt.pie(result,labels=result.index,autopct='%0.2f')
plt.show()
#plt.la

# %% [markdown]
# ### 17. Create a pandas series from below dictionary where indices are subjects:
#     {'English':{'Sam':60,'Jackson':74,'Ahree':85},
# 'History':{'Gloria':83,'Sam':65,'Isla':78,'Aron':72,'Gray':61},
# 'Geography':{'Jackson':92,'Gloria':95,'Isla':82,'Aron':75,'Ahree':76},
# 'Mathematics':{'Sam':99,'Gloria':74,'Jackson':89,'Ahree':85,'Gray':95},
# 'Science':{'Sam':89,'Aron':82,'Gray':78,'Isla':93,'Ahree':87}
# }

# %%
data = {'English':{'Sam':60,'Jackson':74,'Ahree':85}, 
'History':{'Gloria':83,'Sam':65,'Isla':78,'Aron':72,'Gray':61},
'Geography':{'Jackson':92,'Gloria':95,'Isla':82,'Aron':75,'Ahree':76},
'Mathematics':{'Sam':99,'Gloria':74,'Jackson':89,'Ahree':85,'Gray':95},
'Science':{'Sam':89,'Aron':82,'Gray':78,'Isla':93,'Ahree':87}
}
series = pd.Series(data).apply(pd.Series)
series
# Out:
#               Sam  Jackson  Ahree  Gloria  Isla  Aron  Gray
# English      60.0     74.0   85.0     NaN   NaN   NaN   NaN
# History      65.0      NaN    NaN    83.0  78.0  72.0  61.0
# Geography     NaN     92.0   76.0    95.0  82.0  75.0   NaN
# Mathematics  99.0     89.0   85.0    74.0   NaN   NaN  95.0
# Science      89.0      NaN   87.0     NaN  93.0  82.0  78.0

# %% [markdown]
# ### 18. Convert the above series into DataFrame and replace the null values with zeroes.

# %%
df = pd.DataFrame(series).fillna(0)
df
# Out:
#               Sam  Jackson  Ahree  Gloria  Isla  Aron  Gray
# English      60.0     74.0   85.0     0.0   0.0   0.0   0.0
# History      65.0      0.0    0.0    83.0  78.0  72.0  61.0
# Geography     0.0     92.0   76.0    95.0  82.0  75.0   0.0
# Mathematics  99.0     89.0   85.0    74.0   0.0   0.0  95.0
# Science      89.0      0.0   87.0     0.0  93.0  82.0  78.0

# %% [markdown]
# ### 19. Transpose the DataFrame and create a new column Average fill it by calculating average of all subjects.

# %%
df_t = df.T
df_t
# Out:
#          English  History  Geography  Mathematics  Science
# Sam         60.0     65.0        0.0         99.0     89.0
# Jackson     74.0      0.0       92.0         89.0      0.0
# Ahree       85.0      0.0       76.0         85.0     87.0
# Gloria       0.0     83.0       95.0         74.0      0.0
# Isla         0.0     78.0       82.0          0.0     93.0
# Aron         0.0     72.0       75.0          0.0     82.0
# Gray         0.0     61.0        0.0         95.0     78.0

# %%
df_t['Average'] = df_t.apply(lambda x: x.mean(),axis=1)
df_t
# Out:
#          English  History  Geography  Mathematics  Science    Average
# Sam         60.0     65.0        0.0         99.0     89.0  62.166667
# Jackson     74.0      0.0       92.0         89.0      0.0  54.833333
# Ahree       85.0      0.0       76.0         85.0     87.0  69.666667
# Gloria       0.0     83.0       95.0         74.0      0.0  42.000000
# Isla         0.0     78.0       82.0          0.0     93.0  42.166667
# Aron         0.0     72.0       75.0          0.0     82.0  38.166667
# Gray         0.0     61.0        0.0         95.0     78.0  39.000000

# %%
car_sales_df = pd.read_csv('Car_sales.csv')
car_sales_df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
# 2        3.470           17.2             26.0      1/4/2012
# 3        3.850           18.0             22.0     3/10/2011
# 4        2.998           16.4             27.0     10/8/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778
# 2                NaN
# 3          91.389779
# 4          62.777639

# %%
insurance_car_df = pd.read_csv('USA_cars_datasets.csv', index_col=[0])
insurance_car_df.head()
# Out:
#    price      brand    model  year   title_status   mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1   2899       ford       se  2011  clean vehicle  190552.0  silver
# 2   5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3  25000       ford     door  2014  clean vehicle   64146.0    blue
# 4  27700  chevrolet     1500  2018  clean vehicle    6654.0     red
#
#                    vin        lot       state country      condition
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
print(car_sales_df.shape)
print(insurance_car_df.shape)
# Out:
# (157, 16)
# (2499, 12)

# %%
car_sales_df['Manufacturer'] = car_sales_df['Manufacturer'].str.lower()
car_sales_df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        acura  Integra              16.919               16.360    Passenger
# 1        acura       TL              39.384               19.875    Passenger
# 2        acura       CL              14.114               18.225    Passenger
# 3        acura       RL               8.588               29.725    Passenger
# 4         audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
# 2        3.470           17.2             26.0      1/4/2012
# 3        3.850           18.0             22.0     3/10/2011
# 4        2.998           16.4             27.0     10/8/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778
# 2                NaN
# 3          91.389779
# 4          62.777639

# %%
result = pd.merge(car_sales_df, insurance_car_df,left_on='Manufacturer',right_on='brand', how='left')
result.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        acura  Integra              16.919               16.360    Passenger
# 1        acura  Integra              16.919               16.360    Passenger
# 2        acura  Integra              16.919               16.360    Passenger
# 3        acura       TL              39.384               19.875    Passenger
# 4        acura       TL              39.384               19.875    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  ...  model  \
# 0                21.5          1.8       140.0      101.2   67.3  ...   door
# 1                21.5          1.8       140.0      101.2   67.3  ...   door
# 2                21.5          1.8       140.0      101.2   67.3  ...    mdx
# 3                28.4          3.2       225.0      108.1   70.3  ...   door
# 4                28.4          3.2       225.0      108.1   70.3  ...   door
#
#      year       title_status   mileage   color                  vin  \
# 0  2008.0  salvage insurance  118250.0    gray    5j8tb18578a010979
# 1  2009.0      clean vehicle  179389.0   black    19uua96529a004646
# 2  2014.0      clean vehicle   63500.0  silver    5fryd3h20eb002546
# 3  2008.0  salvage insurance  118250.0    gray    5j8tb18578a010979
# 4  2009.0      clean vehicle  179389.0   black    19uua96529a004646
#
#            lot     state country     condition
# 0  167362709.0  michigan     usa   2 days left
# 1  167389316.0     texas     usa  2 hours left
# 2  167775829.0   florida     usa   1 days left
# 3  167362709.0  michigan     usa   2 days left
# 4  167389316.0     texas     usa  2 hours left
#
# [5 rows x 28 columns]

# %%
result.shape
# Out:
# (23794, 28)

# %%
for col in car_sales_df.columns:
    if car_sales_df[col].dtype == 'float64':
        car_sales_df[col].fillna(car_sales_df[col].mean(), inplace=True)
    else:
        car_sales_df[col].fillna(car_sales_df[col].mode(), inplace=True)

# %%
car_sales_df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        acura  Integra              16.919               16.360    Passenger
# 1        acura       TL              39.384               19.875    Passenger
# 2        acura       CL              14.114               18.225    Passenger
# 3        acura       RL               8.588               29.725    Passenger
# 4         audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0           21.500000          1.8       140.0      101.2   67.3   172.4
# 1           28.400000          3.2       225.0      108.1   70.3   192.9
# 2           27.390755          3.2       225.0      106.9   70.6   192.0
# 3           42.000000          3.5       210.0      114.6   71.4   196.6
# 4           23.990000          1.8       150.0      102.6   68.2   178.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
# 2        3.470           17.2             26.0      1/4/2012
# 3        3.850           18.0             22.0     3/10/2011
# 4        2.998           16.4             27.0     10/8/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778
# 2          77.043591
# 3          91.389779
# 4          62.777639

# %%
car_sales_df.isna().any()
# Out:
# Manufacturer           False
# Model                  False
# Sales_in_thousands     False
# __year_resale_value    False
# Vehicle_type           False
# Price_in_thousands     False
# Engine_size            False
# Horsepower             False
# Wheelbase              False
# Width                  False
# Length                 False
# Curb_weight            False
# Fuel_capacity          False
# Fuel_efficiency        False
# Latest_Launch          False
# Power_perf_factor      False
# dtype: bool

# %% [markdown]
# ### 2. Group by manufacturer and print the average 4- year resale value in descending order.

# %%
car_sales_df.groupby('Manufacturer')['__year_resale_value'].mean().sort_values(ascending=False).head()
# Out:
# Manufacturer
# porsche       56.475000
# mercedes-b    29.648875
# audi          28.270000
# bmw           27.624325
# lexus         25.607321
# Name: __year_resale_value, dtype: float64

# %% [markdown]
# ### 23. Find the best fuel efficient Model and Manufacturer.

# %%
car_sales_df[car_sales_df['Fuel_efficiency'] == car_sales_df['Fuel_efficiency'].max()][['Manufacturer','Model']]
# Out:
#    Manufacturer  Model
# 26    chevrolet  Metro

# %% [markdown]
# ### 24. Print details of models made by Audi using group by method.

# %%
group = car_sales_df.groupby('Manufacturer')
group.get_group('audi')
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 4         audi    A4              20.397               22.255    Passenger
# 5         audi    A6              18.780               23.555    Passenger
# 6         audi    A8               1.380               39.000    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
# 6               62.00          4.2       310.0      113.0   74.0   198.2
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 4        2.998           16.4             27.0     10/8/2011
# 5        3.561           18.5             22.0      8/9/2011
# 6        3.902           23.7             21.0     2/27/2012
#
#    Power_perf_factor
# 4          62.777639
# 5          84.565105
# 6         134.656858

# %%
result.loc['audi']
# Out:
# 4    True
# 5    True
# 6    True
# Name: Manufacturer, dtype: bool

# %%
car_sales_df.iloc[result.loc['audi'].index]
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 4         audi    A4              20.397               22.255    Passenger
# 5         audi    A6              18.780               23.555    Passenger
# 6         audi    A8               1.380               39.000    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
# 6               62.00          4.2       310.0      113.0   74.0   198.2
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 4        2.998           16.4             27.0     10/8/2011
# 5        3.561           18.5             22.0      8/9/2011
# 6        3.902           23.7             21.0     2/27/2012
#
#    Power_perf_factor
# 4          62.777639
# 5          84.565105
# 6         134.656858

# %% [markdown]
# ### 25. Print the data of car where sales in thousands is between 200 to 300.

# %%
car_sales_df[(car_sales_df['Sales_in_thousands']>200) & (car_sales_df['Sales_in_thousands']<300)]
# Out:
#     Manufacturer       Model  Sales_in_thousands  __year_resale_value  \
# 40         dodge  Ram Pickup             227.061               15.060
# 49          ford      Taurus             245.815               10.055
# 52          ford    Explorer             276.747               16.640
# 55          ford      Ranger             220.650                7.850
# 58         honda      Accord             230.902               13.210
# 137       toyota       Camry             247.994               13.245
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 40           Car              19.460          5.2       230.0      138.7
# 49     Passenger              17.885          3.0       155.0      108.5
# 52           Car              31.930          4.0       210.0      111.6
# 55           Car              12.050          2.5       119.0      117.5
# 58     Passenger              15.350          2.3       135.0      106.9
# 137    Passenger              17.518          2.2       133.0      105.2
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 40    79.3   224.2        4.470           26.0             17.0      3/6/2012
# 49    73.0   197.6        3.368           16.0             24.0    12/20/2011
# 52    70.2   190.7        3.876           21.0             19.0     4/25/2012
# 55    69.4   200.7        3.086           20.0             23.0     1/14/2012
# 58    70.3   188.8        2.932           17.1             27.0     5/20/2012
# 137   70.1   188.5        2.998           18.5             27.0     2/10/2011
#
#      Power_perf_factor
# 40           90.211700
# 49           62.503740
# 52           87.635496
# 55           47.389531
# 58           54.269548
# 137          54.372420

# %% [markdown]
# ### 26. Random sample 20 rows from the dataset

# %%
help(car_sales_df.sample)
# Out:
# Help on method sample in module pandas.core.generic:
#
# sample(n=None, frac=None, replace=False, weights=None, random_state=None, axis=None) -> 'FrameOrSeries' method of pandas.core.frame.DataFrame instance
#     Return a random sample of items from an axis of object.
#
#     You can use `random_state` for reproducibility.
#
#     Parameters
#     ----------
#     n : int, optional
#         Number of items from axis to return. Cannot be used with `frac`.
#         Default = 1 if `frac` = None.
#     frac : float, optional
#         Fraction of axis items to return. Cannot be used with `n`.
#     replace : bool, default False
#         Allow or disallow sampling of the same row more than once.
#     weights : str or ndarray-like, optional
#         Default 'None' results in equal probability weighting.
#         If passed a Series, will align with target object on index. Index
#         values in weights not found in sampled object will be ignored and
#         index values in sampled object not in weights will be assigned
#         weights of zero.
#         If called on a DataFrame, will accept the name of a column
#         when axis = 0.
#         Unless weights are a Series, weights must be same length as axis
#         being sampled.
#         If weights do not sum to 1, they will be normalized to sum to 1.
#         Missing values in the weights column will be treated as zero.
#         Infinite values not allowed.
#     random_state : int, array-like, BitGenerator, np.random.RandomState, optional
#         If int, array-like, or BitGenerator (NumPy>=1.17), seed for
#         random number generator
#         If np.random.RandomState, use as numpy RandomState object.
#
#         .. versionchanged:: 1.1.0
#
#             array-like and BitGenerator (for NumPy>=1.17) object now passed to
#             np.random.RandomState() as seed
#
#     axis : {0 or ‘index’, 1 or ‘columns’, None}, default None
#         Axis to sample. Accepts axis number or name. Default is stat axis
#         for given data type (0 for Series and DataFrames).
#
#     Returns
#     -------
#     Series or DataFrame
#         A new object of same type as caller containing `n` items randomly
#         sampled from the caller object.
#
#     See Also
#     --------
#     DataFrameGroupBy.sample: Generates random samples from each group of a
#         DataFrame object.
#     SeriesGroupBy.sample: Generates random samples from each group of a
#         Series object.
#     numpy.random.choice: Generates a random sample from a given 1-D numpy
#         array.
#
#     Notes
#     -----
#     If `frac` > 1, `replacement` should be set to `True`.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'num_legs': [2, 4, 8, 0],
#     ...                    'num_wings': [2, 0, 0, 0],
#     ...                    'num_specimen_seen': [10, 2, 1, 8]},
#     ...                   index=['falcon', 'dog', 'spider', 'fish'])
#     >>> df
#             num_legs  num_wings  num_specimen_seen
#     falcon         2          2                 10
#     dog            4          0                  2
#     spider         8          0                  1
#     fish           0          0                  8
#
#     Extract 3 random elements from the ``Series`` ``df['num_legs']``:
#     Note that we use `random_state` to ensure the reproducibility of
#     the examples.
#
#     >>> df['num_legs'].sample(n=3, random_state=1)
#     fish      0
#     spider    8
#     falcon    2
#     Name: num_legs, dtype: int64
#
#     A random 50% sample of the ``DataFrame`` with replacement:
#
#     >>> df.sample(frac=0.5, replace=True, random_state=1)
#           num_legs  num_wings  num_specimen_seen
#     dog          4          0                  2
#     fish         0          0                  8
#
#     An upsample sample of the ``DataFrame`` with replacement:
#     Note that `replace` parameter has to be `True` for `frac` parameter > 1.
#
#     >>> df.sample(frac=2, replace=True, random_state=1)
#             num_legs  num_wings  num_specimen_seen
#     dog            4          0                  2
#     fish           0          0                  8
#     falcon         2          2                 10
#     falcon         2          2                 10
#     fish           0          0                  8
#     dog            4          0                  2
#     fish           0          0                  8
#     dog            4          0                  2
#
#     Using a DataFrame column as weights. Rows with larger value in the
#     `num_specimen_seen` column are more likely to be sampled.
#
#     >>> df.sample(n=2, weights='num_specimen_seen', random_state=1)
#             num_legs  num_wings  num_specimen_seen
#     falcon         2          2                 10
#     fish           0          0                  8

# %%
car_sales_df.sample(20)
# Out:
#     Manufacturer       Model  Sales_in_thousands  __year_resale_value  \
# 156        volvo         S80              18.969            18.072975
# 2          acura          CL              14.114            18.225000
# 102       nissan      Altima              88.094            11.295000
# 45         dodge     Caravan             181.749            12.025000
# 114     plymouth        Neon              32.734             7.750000
# 32      chrysler         LHS              13.462            17.325000
# 81    mitsubishi      Galant              55.616            10.595000
# 133       saturn          LS              49.989            18.072975
# 39         dodge       Viper               0.916            58.470000
# 128         saab       3-Sep              12.115            18.072975
# 67          jeep    Wrangler              55.557            13.475000
# 35         dodge        Neon              76.034             7.750000
# 20     chevrolet      Malibu             135.126            11.225000
# 25     chevrolet       Prizm              32.299             9.125000
# 110   oldsmobile       Alero              80.255            18.072975
# 18      cadillac    Escalade              14.785            18.072975
# 57         honda       Civic             199.685             9.850000
# 26     chevrolet       Metro              21.855             5.160000
# 121      pontiac  Grand Prix              92.364            14.010000
# 36         dodge     Avenger               4.734            12.545000
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 156    Passenger           36.000000          2.9       201.0      109.9
# 2      Passenger           27.390755          3.2       225.0      106.9
# 102    Passenger           20.390000          2.4       155.0      103.1
# 45           Car           19.565000          2.4       150.0      113.3
# 114    Passenger           12.640000          2.0       132.0      105.0
# 32     Passenger           28.340000          3.5       253.0      113.0
# 81     Passenger           17.357000          2.4       145.0      103.7
# 133    Passenger           15.010000          2.2       137.0      106.5
# 39     Passenger           69.725000          8.0       450.0       96.2
# 128    Passenger           26.100000          2.0       185.0      102.6
# 67           Car           14.460000          2.5       120.0       93.4
# 35     Passenger           12.640000          2.0       132.0      105.0
# 20     Passenger           16.535000          3.1       170.0      107.0
# 25     Passenger           13.960000          1.8       120.0       97.1
# 110    Passenger           18.270000          2.4       150.0      107.0
# 18           Car           46.225000          5.7       255.0      117.5
# 57     Passenger           12.885000          1.6       106.0      103.2
# 26     Passenger            9.235000          1.0        55.0       93.1
# 121    Passenger           21.665000          3.8       195.0      110.5
# 36     Passenger           19.045000          2.5       163.0      103.7
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 156   72.1   189.8        3.600           21.1             24.0    11/14/2011
# 2     70.6   192.0        3.470           17.2             26.0      1/4/2012
# 102   69.1   183.5        3.012           15.9             25.0      8/2/2011
# 45    76.8   186.3        3.533           20.0             24.0      9/1/2011
# 114   74.4   174.4        2.559           12.5             29.0     4/26/2011
# 32    74.4   207.7        3.564           17.0             23.0      5/8/2012
# 81    68.5   187.8        2.945           16.3             25.0     1/29/2012
# 133   69.0   190.4        2.910           13.1             28.0     12/4/2012
# 39    75.7   176.7        3.375           19.0             16.0      8/7/2011
# 128   67.4   182.2        2.990           16.9             23.0     6/12/2011
# 67    66.7   152.0        3.045           19.0             17.0      3/4/2012
# 35    74.4   174.4        2.567           12.5             29.0    12/12/2011
# 20    69.4   190.4        3.051           15.0             25.0     3/19/2012
# 25    66.7   174.3        2.398           13.2             33.0     9/11/2011
# 110   70.1   186.7        2.958           15.0             27.0    10/20/2009
# 18    77.0   201.2        5.572           30.0             15.0     4/17/2012
# 57    67.1   175.1        2.339           11.9             32.0    10/21/2011
# 26    62.6   149.4        1.895           10.3             45.0     4/13/2012
# 121   72.7   196.5        3.396           18.0             25.0    10/15/2012
# 36    69.1   190.2        2.879           15.9             24.0      7/1/2012
#
#      Power_perf_factor
# 156          85.735655
# 2            77.043591
# 102          63.313728
# 45           61.227000
# 114          52.084899
# 32          101.329281
# 81           58.606773
# 133          54.819728
# 39          188.144323
# 128          76.023048
# 67           48.672898
# 35           52.084899
# 20           67.314462
# 25           48.297636
# 110          60.727447
# 18          109.509117
# 57           42.879097
# 26           23.276272
# 121          78.318168
# 36           65.650508

# %% [markdown]
# ### 27. Given below are two DataFrame perform left and right joins respoectively.

# %%
df1 = pd.DataFrame({'Name': ['Sam', 'Aron', 'Smith','Lee','Gloria'] ,
 'Age': [18, 27, 18, 27, 17] ,
 'Hobby': ['music','binge-watching','dancing','music','music']})
df2 = pd.DataFrame({'Name': ['Sam', 'Aron', 'Smith','Janna','Cohle'] ,
 'Age': [23, 21, 21, 25, 18],
 'Hobby': ['painting','dancing','dancing','gaming','binge-watching']})

# %%
df1
# Out:
#      Name  Age           Hobby
# 0     Sam   18           music
# 1    Aron   27  binge-watching
# 2   Smith   18         dancing
# 3     Lee   27           music
# 4  Gloria   17           music

# %%
df2
# Out:
#     Name  Age           Hobby
# 0    Sam   23        painting
# 1   Aron   21         dancing
# 2  Smith   21         dancing
# 3  Janna   25          gaming
# 4  Cohle   18  binge-watching

# %%
# Left Join
pd.merge(df1, df2,left_on='Name',right_on='Name', how='left')
# Out:
#      Name  Age_x         Hobby_x  Age_y   Hobby_y
# 0     Sam     18           music   23.0  painting
# 1    Aron     27  binge-watching   21.0   dancing
# 2   Smith     18         dancing   21.0   dancing
# 3     Lee     27           music    NaN       NaN
# 4  Gloria     17           music    NaN       NaN

# %%
# Right Join
pd.merge(df1, df2,left_on='Name',right_on='Name', how='right')
# Out:
#     Name  Age_x         Hobby_x  Age_y         Hobby_y
# 0    Sam   18.0           music     23        painting
# 1   Aron   27.0  binge-watching     21         dancing
# 2  Smith   18.0         dancing     21         dancing
# 3  Janna    NaN             NaN     25          gaming
# 4  Cohle    NaN             NaN     18  binge-watching

# %% [markdown]
# ### 28. Create pandas dataframe having keys and ltable and rtable as below -
#   'key': ['One', 'Two'], 'ltable': [1, 2]
#   'key': ['One', 'Two'], 'rtable': [4, 5]
#   Merge both the tables based of key

# %%
df1 = pd.DataFrame({'key': ['One', 'Two'], 'ltable': [1, 2]})
df2 = pd.DataFrame({'key': ['One', 'Two'], 'rtable': [4, 5]})

# %%
df1
# Out:
#    key  ltable
# 0  One       1
# 1  Two       2

# %%
df2
# Out:
#    key  rtable
# 0  One       4
# 1  Two       5

# %%
pd.merge(df1, df2, how='inner', left_on=['key'], right_on= ['key'])
# Out:
#    key  ltable  rtable
# 0  One       1       4
# 1  Two       2       5

# %% [markdown]
# ### 29. Create a Python DataFrame from the below data:

# %%
fruits=pd.DataFrame({'Food':['Blueberries','Cranberries','Cherrries','Coconut'],
 'PortionSize':['100g','100g','120g','110g'],
 'Calories': [30,15,39,351],
 'K joules':[128,65,168,1446]})
fruits
# Out:
#           Food PortionSize  Calories  K joules
# 0  Blueberries        100g        30       128
# 1  Cranberries        100g        15        65
# 2    Cherrries        120g        39       168
# 3      Coconut        110g       351      1446

# %% [markdown]
# ### 30. Calculate the percentile rank of the Test_score column and add a new column specifying the percentiles.

# %%
my_dict={'Name':['Gloria','Aron','Janna','Mia','Jackson','Sylphia','Jim'],
 'Test_score':[52,73,65,84,62,66,93]}
df = pd.DataFrame(my_dict)
df
# Out:
#       Name  Test_score
# 0   Gloria          52
# 1     Aron          73
# 2    Janna          65
# 3      Mia          84
# 4  Jackson          62
# 5  Sylphia          66
# 6      Jim          93

# %%
df['Percentiles'] = df['Test_score'].rank(pct=True)
df
# Out:
#       Name  Test_score  Percentiles
# 0   Gloria          52     0.142857
# 1     Aron          73     0.714286
# 2    Janna          65     0.428571
# 3      Mia          84     0.857143
# 4  Jackson          62     0.285714
# 5  Sylphia          66     0.571429
# 6      Jim          93     1.000000

# %%
np.percentile(df['Test_score'],52)
# Out:
# 66.84

# %%
df['Test_score'].quantile()
# Out:
# 66.0
